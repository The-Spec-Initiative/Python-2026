# %% [markdown]
# source: Kaggle.com

# %% [markdown]
# 1. **What is your favorite color? **
#
# To complete this question, create a variable called color in a cell below with an appropriate value.

# %%
color ="red"
print("My favorite","" + color)
# Out:
# My favorite red

# %% [markdown]
# 2. Write a piece of code that calculates the circumference of a circle.
# hint:
# 𝐶=2𝜋𝑟
# 𝜋 = 3.14159
#
#
# cool to try: utilize the Math library to determine PI.

# %%
Circumference = 2 * 3.14159 * 4
print (Circumference)
# Out:
# 25.13272

# %% [markdown]
# 3. Write a piece of code that calculates the Area of a circle.
# hint:
# A = 𝜋𝑟^2

# %%
Area = 3.14159 * 4**2
print (Area)
# Out:
# 50.26544

# %% [markdown]
# 4. Swap the values to which a and b refer.
# print the output for both values.
# eg:  a becomes values of b and vice versa
#
# cool to try: use a tupple

# %%
a = [1, 2, 3]
b = [3, 2, 1]
(a,b) = (b,a)
print (a)
print (b)
# Out:
# [3, 2, 1]
# [1, 2, 3]

# %% [markdown]
# 5. Add parentheses to the following expression so that it evaluates to 1.

# %%
(5 - 3) // 2
# Out:
# 1

# %% [markdown]
# 6. Add parentheses to the following expression so that it evaluates to 0.

# %%
(8 - (3 * 2)) - (1 + 1)
# Out:
# 0

# %% [markdown]
# 7. Alice, Bob and Carol have agreed to pool their Halloween candy and split it evenly among themselves. For the sake of their friendship, any candies left over will be thrown away.
#
# Write an arithmetic expression below to calculate how many candies they must throw away.
#
# hint: modulo

# %%
alice_candies = 121
bob_candies = 77
carol_candies = 109

throwAway = (109 + 77 + 121) % 3
print (throwAway)
# Out:
# 1
